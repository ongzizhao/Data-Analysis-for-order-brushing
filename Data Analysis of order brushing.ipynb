# %%
import pandas as pd
import numpy as np
data=pd.read_csv("Copy of Copy of order_brush_order.csv")
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222750 entries, 0 to 222749
# Data columns (total 4 columns):
# orderid       222750 non-null int64
# shopid        222750 non-null int64
# userid        222750 non-null int64
# event_time    222750 non-null object
# dtypes: int64(3), object(1)
# memory usage: 6.8+ MB

# %%
data.head()
# Out:
#           orderid     shopid     userid           event_time
# 0  31076582227611   93950878   30530270  2019-12-27 00:23:03
# 1  31118059853484  156423439   46057927  2019-12-27 11:54:20
# 2  31123355095755  173699291   67341739  2019-12-27 13:22:35
# 3  31122059872723   63674025  149380322  2019-12-27 13:01:00
# 4  31117075665123  127249066  149493217  2019-12-27 11:37:55

# %%
shop_id=data["shopid"].unique().tolist()
data_by_shop=[data[data["shopid"]==id] for id in shop_id]

# %%
data_sample=data_by_shop[:10]

# %%
data_sample
# Out:
# [               orderid    shopid     userid           event_time
#  0       31076582227611  93950878   30530270  2019-12-27 00:23:03
#  4130    31424903151124  93950878  200055785  2019-12-31 01:08:23
#  8774    31328233643619  93950878  103695259  2019-12-29 22:17:13
#  9646    31370827295602  93950878   16996136  2019-12-30 10:07:07
#  18802   31149769932285  93950878  133955528  2019-12-27 20:42:49
#  ...                ...       ...        ...                  ...
#  215692  31212504536727  93950878  139164756  2019-12-28 14:08:24
#  217787  31198732543805  93950878  211964549  2019-12-28 10:18:52
#  218637  31199132288203  93950878   63324212  2019-12-28 10:25:33
#  219095  31105361715982  93950878   88222910  2019-12-27 08:22:41
#  220090  31426313262749  93950878   28265780  2019-12-31 01:31:54
#
#  [124 rows x 4 columns],
#                 orderid     shopid     userid           event_time
#  1       31118059853484  156423439   46057927  2019-12-27 11:54:20
# ...

# %%
sample_id=[]
for data in data_sample:
    sample_id.append(data["shopid"].unique()[0])

# %%
suspicious={}
for id in sample_id:
    suspicious[id]=[]

# %%
suspicious
# Out:
# {93950878: [],
#  156423439: [],
#  173699291: [],
#  63674025: [],
#  127249066: [],
#  173811070: [],
#  107921853: [],
#  178400128: [],
#  147941492: [],
#  164933170: []}

# %%
data
# Out:
#                orderid     shopid     userid           event_time
# 9       31133458226149  164933170  135957741  2019-12-27 16:10:59
# 98257   31219447259040  164933170  116564768  2019-12-28 16:04:07
# 112931  31300114639622  164933170  130593251  2019-12-29 14:28:35
# 127213  31246573103657  164933170   61847415  2019-12-28 23:36:13
# 146997  31491763673835  164933170  154212411  2019-12-31 19:42:43
# 169290  31477364164371  164933170   69249880  2019-12-31 15:42:44
# 181330  31203757843575  164933170    7491786  2019-12-28 11:42:38
# 197799  31392071363491  164933170  175366335  2019-12-30 16:01:11

# %%
dataX=pd.read_csv("Copy of Copy of order_brush_order.csv")

# %%
test_sample=dataX[dataX["shopid"]==8715449]

# %%
test_sample["userid"].value_counts()
# Out:
# 9753706      3
# 40849320     2
# 118510472    2
# 134649236    2
# 757001       2
#             ..
# 31867306     1
# 182441       1
# 123448915    1
# 65991274     1
# 150252878    1
# Name: userid, Length: 165, dtype: int64
